# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from gstatsMCMC import Topography
from gstatsMCMC import MCMC
import gstatsim as gs
from sklearn.preprocessing import QuantileTransformer
import skgstat as skg
import cmocean

# %%
steps=np.loadtxt('Rutford_sgs_steps_0.txt')

# %%
window = 100
accept_rate = np.convolve(steps, np.ones(window)/window, mode='valid')

plt.figure()

# Rolling acceptance rate
plt.plot(range(window-1, len(steps)), accept_rate,
         label='Acceptance rate (window=100)', linewidth=2)

plt.xlabel('Iteration')
plt.ylabel('Acceptance Rate')
plt.ylim(0, 1)
plt.legend()
plt.title('MCMC Acceptance Rate Over Time')

plt.show()

# %%
steps=np.loadtxt('Rutford_sgs_steps_4000.txt')

# %%
window = 100
accept_rate = np.convolve(steps, np.ones(window)/window, mode='valid')

plt.figure()

# Rolling acceptance rate
plt.plot(range(window-1, len(steps)), accept_rate,
         label='Acceptance rate (window=100)', linewidth=2)

plt.xlabel('Iteration')
plt.ylabel('Acceptance Rate')
plt.ylim(0, 1)
plt.legend()
plt.title('MCMC Acceptance Rate Over Time')

plt.show()

# %%
loss=np.loadtxt('Rutford_sgs_loss_0.txt')

# %%
plt.plot(loss)
plt.xlabel('Iteration');
plt.ylabel('Loss');
plt.title('MCMC Loss')
plt.show()

# %%
loss=np.loadtxt('Rutford_sgs_loss_4000.txt')

# %%
plt.plot(loss)
plt.xlabel('Iteration');
plt.ylabel('Loss');
plt.title('MCMC Loss')
plt.show()
